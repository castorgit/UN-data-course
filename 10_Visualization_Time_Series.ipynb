# %%
# Visualizar Time Series

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from matplotlib.ticker import FuncFormatter
from matplotlib.dates import DateFormatter, MonthLocator
import matplotlib.dates as mdates

# %%
file = "./data/Births_in_Canada_2000_2022.xlsx"
df =  pd.read_excel(file, sheet_name='Sheet',  index_col=[0], header=[0])

df.reset_index(inplace=True)

df['Date'] = pd.to_datetime(df['Year of birth'].astype(str) + '-' + df['Month of birth'].astype(str) + '-01')
df
# Out:
#     Month of birth  Year of birth  Number of live births       Date
# 0          January           2000                  27288 2000-01-01
# 1         February           2000                  26245 2000-02-01
# 2            March           2000                  29277 2000-03-01
# 3            April           2000                  28257 2000-04-01
# 4              May           2000                  29881 2000-05-01
# ..             ...            ...                    ...        ...
# 271         August           2022                  31706 2022-08-01
# 272      September           2022                  30472 2022-09-01
# 273        October           2022                  29671 2022-10-01
# 274       November           2022                  28428 2022-11-01
# 275       December           2022                  27540 2022-12-01
#
# [276 rows x 4 columns]

# %%
# (1) Births per month Canada
# Source Statistics Canada

ts1 = df.copy()

ts1.set_index('Date',inplace=True)

fig, ax = plt.subplots(figsize=(24,8))

plt.title('Births per Year in Canada', fontsize=24)


sns.lineplot(data=ts1, x='Date', y='Number of live births', markers=True, dashes=False, linewidth=5, 
             alpha=0.9, label='Number of live births')



plt.fill_between(ts1.index, ts1['Number of live births'], color="palegreen", alpha=0.3)


ax.grid(which='minor', alpha=0.8)  
ax.set_facecolor('whitesmoke')
plt.grid()
plt.legend(loc="upper right", fontsize=20)
plt.tight_layout()
plt.tick_params(labelsize=20)

#ax.xaxis.set_major_locator(MonthLocator(interval=3))
#ax.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax.xaxis.set_major_locator(mdates.YearLocator())  # Ticks at January of every year
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))


plt.xticks(rotation=45)

def thousands_formatter(x,pos):
    return f'{x:,.0f}'

# Set the formatter for the y-axis
ax.yaxis.set_major_formatter(FuncFormatter(thousands_formatter))
#plt.savefig('./data/figures/EDA3-04.png')
plt.ylabel("Number of live Births", fontsize=20)
plt.xlabel("Date", fontsize=20)
plt.yticks(fontsize=20)
plt.ylim(24000, 35000)
plt.tight_layout()
plt.savefig('./figures/01_Births_in_Canada.png')
plt.show()

# %% [markdown]
# #### Milk production in UK

# %%
file = "./data/Milk_Dataset.xlsx"
df =  pd.read_excel(file, sheet_name='Sheet',  index_col=[0], header=[0])

df.reset_index(inplace=True)
df['Date'] = pd.to_datetime(df['Month'].astype(str))
df
# Out:
#          Month  Month production       Date
# 0   1962-01-01               589 1962-01-01
# 1   1962-02-01               561 1962-02-01
# 2   1962-03-01               640 1962-03-01
# 3   1962-04-01               656 1962-04-01
# 4   1962-05-01               727 1962-05-01
# ..         ...               ...        ...
# 163 1975-08-01               858 1975-08-01
# 164 1975-09-01               817 1975-09-01
# 165 1975-10-01               827 1975-10-01
# 166 1975-11-01               797 1975-11-01
# 167 1975-12-01               843 1975-12-01
#
# [168 rows x 3 columns]

# %%
# (2) Milk Production in UK
# UK Statistics

ts1 = df.copy()

ts1.set_index('Date',inplace=True)

fig, ax = plt.subplots(figsize=(24,8))

plt.title('Milk Production in UK', fontsize=24)


sns.lineplot(data=ts1, x='Date', y='Month production', markers=True, dashes=False, linewidth=5, 
             alpha=0.9, label='Milk Production', color='goldenrod')

plt.fill_between(ts1.index, ts1['Month production'], color="cornsilk", alpha=0.3)


ax.grid(which='minor', alpha=0.8)  
ax.set_facecolor('whitesmoke')
plt.grid()
plt.legend(loc="upper right", fontsize=20)
plt.tight_layout()
plt.tick_params(labelsize=20)

#ax.xaxis.set_major_locator(MonthLocator(interval=3))
#ax.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax.xaxis.set_major_locator(mdates.YearLocator())  # Ticks at January of every year
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))


plt.xticks(rotation=45)

def thousands_formatter(x,pos):
    return f'{x:,.0f}'

# Set the formatter for the y-axis
ax.yaxis.set_major_formatter(FuncFormatter(thousands_formatter))
#plt.savefig('./data/figures/EDA3-04.png')
plt.ylabel("Milk Production per month", fontsize=20)
plt.xlabel("Date", fontsize=20)
plt.yticks(fontsize=20)
plt.ylim(500,1000)
plt.tight_layout()
plt.savefig('./figures/01_Milk_Production_UK.png')
plt.show()

# %% [markdown]
# #### Champagne Sales

# %%
file = "./data/Champagne_sales.xlsx"
df =  pd.read_excel(file, sheet_name='Sheet',  index_col=[0], header=[0])
df.reset_index(inplace=True)
df['Date'] = pd.to_datetime(df['Month'].astype(str))
df
# Out:
#          Month  Sales       Date
# 0   1964-01-01   2815 1964-01-01
# 1   1964-02-01   2672 1964-02-01
# 2   1964-03-01   2755 1964-03-01
# 3   1964-04-01   2721 1964-04-01
# 4   1964-05-01   2946 1964-05-01
# ..         ...    ...        ...
# 100 1972-05-01   4618 1972-05-01
# 101 1972-06-01   5312 1972-06-01
# 102 1972-07-01   4298 1972-07-01
# 103 1972-08-01   1413 1972-08-01
# 104 1972-09-01   5877 1972-09-01
#
# [105 rows x 3 columns]

# %%
# (2) Milk Production in UK
# UK Statistics

ts1 = df.copy()

ts1.set_index('Date',inplace=True)

fig, ax = plt.subplots(figsize=(24,8))

plt.title('Champagne Sales', fontsize=24)


sns.lineplot(data=ts1, x='Date', y='Sales', markers=True, dashes=False, linewidth=5, 
             alpha=0.9, label='Monthly Sales', color='orchid')

plt.fill_between(ts1.index, ts1['Sales'], color="lightpink", alpha=0.3)


ax.grid(which='minor', alpha=0.8)  
ax.set_facecolor('whitesmoke')
plt.grid()
plt.legend(loc="upper right", fontsize=20)
plt.tight_layout()
plt.tick_params(labelsize=20)

#ax.xaxis.set_major_locator(MonthLocator(interval=3))
#ax.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax.xaxis.set_major_locator(mdates.YearLocator())  # Ticks at January of every year
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))


plt.xticks(rotation=45)

def thousands_formatter(x,pos):
    return f'{x:,.0f}'

# Set the formatter for the y-axis
ax.yaxis.set_major_formatter(FuncFormatter(thousands_formatter))
#plt.savefig('./data/figures/EDA3-04.png')
plt.ylabel("Champagne Sales per month", fontsize=20)
plt.xlabel("Date", fontsize=20)
plt.yticks(fontsize=20)
#plt.ylim(500,1000)
plt.tight_layout()
plt.savefig('./figures/01_Champagne_sales.png')
plt.show()

# %% [markdown]
# #### Number of Government employees in Punjab (India)

# %%
file = "./data/Punjav_Govt_employees.xlsx"
df =  pd.read_excel(file, sheet_name='Sheet',  index_col=[0], header=[0])
df.reset_index(inplace=True)
df['Date'] = pd.to_datetime(df['Year'].astype(str))
df.head(3)
# Out:
#    Year  Number of Employees       Date
# 0  2017               310616 2017-01-01
# 1  2016               305197 2016-01-01
# 2  2015               304887 2015-01-01

# %%
# (4) Punjab Employees Government
# India Open Data

ts1 = df.copy()

ts1.set_index('Date',inplace=True)

fig, ax = plt.subplots(figsize=(24,8))

plt.title('Punjav Government Employees', fontsize=24)


sns.lineplot(data=ts1, x='Date', y='Number of Employees', markers=True, dashes=False, linewidth=5, 
             alpha=0.9, label='Number of employees (Year)', color='saddlebrown')

plt.fill_between(ts1.index, ts1['Number of Employees'], color="peachpuff", alpha=0.3)


ax.grid(which='minor', alpha=0.8)  
ax.set_facecolor('whitesmoke')
plt.grid()
plt.legend(loc="upper right", fontsize=20)
plt.tight_layout()
plt.tick_params(labelsize=20)

#ax.xaxis.set_major_locator(MonthLocator(interval=3))
#ax.xaxis.set_major_formatter(DateFormatter("%b %Y"))
ax.xaxis.set_major_locator(mdates.YearLocator())  # Ticks at January of every year
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))


plt.xticks(rotation=45)

def thousands_formatter(x,pos):
    return f'{x:,.0f}'

# Set the formatter for the y-axis
ax.yaxis.set_major_formatter(FuncFormatter(thousands_formatter))
#plt.savefig('./data/figures/EDA3-04.png')
plt.ylabel("Number of Employees", fontsize=20)
plt.xlabel("Date", fontsize=20)
plt.yticks(fontsize=20)
#plt.ylim(500,1000)
plt.tight_layout()
plt.savefig('./figures/01_Punjav_govt_employees.png')
plt.show()
